# %% [markdown]
#                    1 - EDA o Analisis Exploratorio de Datos

# %% [markdown]
#                     EDA (Analisis Exploratorio de Datos)
#                Esta es mi primera prueba con Jupiter Notebook
#              El uso de jupiter notebook es una buena practica para
#                                 convertirme en:
#                 1 - Experta en Python para el Analisis de Datos
#                     [Buscar en:](https://www.google.com)
#                     ![Buscar en:]
#                     (https://images.app.goo.gl/VBFQ9QauRSkznxeq8)

# %%
suma1=2+8
suma2=2+2
SumaT=suma1+suma2
print(SumaT)
# Out:
# 14

# %%
promedio=(suma1+suma2)//4
print(promedio)
print("Lo estas logrando Patricia Parra")

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# - Importamos las librerias al archivo
# - Importamos ahora el archivo CSV o Excel

# %%
df_netflix=pd.read_csv("netflix_titles.csv")

# %% [markdown]
#               Exploracion de datos

# %%
print("primeras filas del Dataframe")
df_netflix.head()
# Out:
# primeras filas del Dataframe
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 print("primeras filas del Dataframe")
# ----> 2 df_netflix.head()
#
# NameError: name 'df_netflix' is not defined

# %%
df_netflix.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_netflix.info()
#
# NameError: name 'df_netflix' is not defined
